# %%
from fastai.vision import *

# %%
folder = 'utility' #'4x4' 'hatchback' 'sedan' 'stationwagon''utility'
file = 'urlsutility.csv' # 'urls4x4.csv' urlshatchback.csv' 'urlssedan.csv' 'urlsstationwagon.csv' 'urlsutility.csv'

# %%
path = Path('cardata')
#dest = path/folder
#dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('cardata/sedan'),
#  PosixPath('cardata/4x4'),
#  PosixPath('cardata/hatchback'),
#  PosixPath('cardata/urlssedan.csv'),
#  PosixPath('cardata/utility'),
#  PosixPath('cardata/urlshatchback.csv'),
#  PosixPath('cardata/urlsstationwagon.csv'),
#  PosixPath('cardata/cleaned.csv'),
#  PosixPath('cardata/urlsutility.csv'),
#  PosixPath('cardata/models'),
#  PosixPath('cardata/urls4x4.csv'),
#  PosixPath('cardata/stationwagon')]

# %%
classes = ['4x4', 'hatchback', 'sedan', 'stationwagon', 'utility']

# %%
# download_images(path/file, dest, max_pics=700)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
np.random.seed(42)
data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['4x4', 'hatchback', 'sedan', 'stationwagon', 'utility']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['4x4', 'hatchback', 'sedan', 'stationwagon', 'utility'], 5, 2421, 605)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate).to_fp16()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-35320f8fa824> in <module>
# ----> 1 learn = cnn_learner(data, models.resnet50, metrics=error_rate).to_fp16()
#
# ~/anaconda3/envs/fastai2019/lib/python3.7/site-packages/fastai/vision/learner.py in cnn_learner(data, base_arch, cut, pretrained, lin_ftrs, ps, custom_head, split_on, bn_final, init, concat_pool, **kwargs)
#      97     model = create_cnn_model(base_arch, data.c, cut, pretrained, lin_ftrs, ps=ps, custom_head=custom_head,
#      98         bn_final=bn_final, concat_pool=concat_pool)
# ---> 99     learn = Learner(data, model, **kwargs)
#     100     learn.split(split_on or meta['split'])
#     101     if pretrained: learn.freeze()
#
# ...

# %%
learn.lr_find()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/fastai2019/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#
# ~/anaconda3/envs/fastai2019/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#
# ~/anaconda3/envs/fastai2019/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
# ...

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.680657</td>
#       <td>1.117676</td>
#       <td>0.439523</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.318058</td>
#       <td>0.951460</td>
#       <td>0.340715</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.135545</td>
#       <td>0.902815</td>
#       <td>0.310051</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.981949</td>
#       <td>0.873249</td>
#       <td>0.315162</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.877945</td>
#       <td>0.830725</td>
#       <td>0.303237</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1_clean')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-5, 3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.579164</td>
#       <td>0.744971</td>
#       <td>0.267462</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.528447</td>
#       <td>0.710416</td>
#       <td>0.253833</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.428100</td>
#       <td>0.633189</td>
#       <td>0.226576</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.344140</td>
#       <td>0.616208</td>
#       <td>0.231687</td>
#       <td>00:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2 clean')

# %%
learn.load('stage-2 clean')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2352 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# sedan,sedan,sedan,sedan,sedan
# Path: cardata;
#
# Valid: LabelList (587 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# utility,4x4,stationwagon,sedan,hatchback
# Path: cardata;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# # Cleaning the dataset

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
                   .split_none()
                   .label_from_df()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)
learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
# Don't run this in google colab or any other instances running jupyter lab.
# If you do run this on Jupyter Lab, you need to restart your runtime and
# runtime state including all local variables will be lost.
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='48' class='' max='48', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [48/48 00:11<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())
